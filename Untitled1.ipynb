# %% [markdown]
# Homework #2 part I
# $$
# \begin{align*}
# &\color{white}{\propto}{} \exp\left[-\frac{1}{2}\left(\left(\sum_{i=1}^n \phi\left(x_i-\theta\right)^2\right)+ \tau\left(\theta-\theta_0\right)^2\right)\right] \\
# &\propto{}
# \exp\left(-\frac{1}{2}  \left(\tau+n\phi\right) \left(\theta - \frac{1}{\tau+n\phi }\left(\tau\theta_0+\phi\sum _{i=1}^{n}x_{i}\right)\right)^2   \right) \\
# \end{align*}$$

# %% [markdown]
# $$
# \exp(-\frac{1}{2}  (\tau+n\phi) (\theta^2 - 2 \theta\frac{1}{\tau+n\phi }(\tau\theta_0+\phi\sum _{i=1}^{n}x_{i}) + (\frac{1}{\tau+n\phi }(\tau\theta_0+\phi\sum _{i=1}^{n}x_{i}))^2   ) \\
# $$

# %% [markdown]
# $$
# \exp(-\frac{1}{2}  (\tau+n\phi) (\theta^2 - 2 \theta\frac{1}{\tau+n\phi }(\tau\theta_0+\phi\sum _{i=1}^{n}x_{i}) + ((\frac{1}{\tau+n\phi })^2(\tau^2\theta_0^2+2\tau\theta_0\phi\sum _{i=1}^{n}x_{i}+(\phi\sum _{i=1}^{n}x_{i})^2))   ) \\
# $$

# %% [markdown]
# $$
# \propto{} \exp(-\frac{1}{2}  (\tau+n\phi) (\theta^2 - 2 \theta\frac{1}{\tau+n\phi }(\tau\theta_0+\phi\sum _{i=1}^{n}x_{i}) + (\tau^2\theta_0^2+2\tau\theta_0\phi\sum _{i=1}^{n}x_{i}))   ) \\
# $$

# %% [markdown]
# $$
# \propto{} \exp(-\frac{1}{2} \theta (\tau+n\phi) (\theta - 2 \frac{1}{\tau+n\phi }(\tau\theta_0+\phi\sum _{i=1}^{n}x_{i}) )   ) \\
# $$

# %% [markdown]
# $$
# \propto{} \exp(\theta)\exp(-\frac{1}{2}  (\tau+n\phi) (\theta - 2 \frac{1}{\tau+n\phi }(\tau\theta_0+\phi\sum _{i=1}^{n}x_{i}) )   ) \\
# $$

# %% [markdown]
# as shown above that this function is a function of $\theta$

# %% [markdown]
# Homework #2 part II

# %% [markdown]
# step 1

# %%
import numpy as np; from scipy import stats; import matplotlib.pyplot as plt
n = 3; x = stats.norm(loc=0,scale=1).rvs(n)
plt.figure()
for xi in range(len(x)):
    likelihood_xi = stats.norm.pdf(x[xi], loc=parameter_domain, scale=1)
    plt.plot(parameter_domain,likelihood_xi)

# %% [markdown]
# step 2

# %%
import numpy as np; from scipy import stats; import matplotlib.pyplot as plt
n = 3; x = stats.norm(loc=0,scale=1).rvs(n)
plt.figure()
for xi in range(len(x)):
    likelihood_xi = stats.norm.logpdf(x[xi], loc=parameter_domain, scale=1)
    plt.plot(parameter_domain,likelihood_xi)

# %% [markdown]
# step 3

# %% [markdown]
# by bayes's theorem:
# $$
# p(\theta|x) \propto{} L(\theta|x) p(\theta)\\
# \propto{} exp(-\frac{(x-\mu)^2}{2\sigma^2})
# $$

# %% [markdown]
# step 4

# %% [markdown]
# by bayes's theorem:
# $$
# p(\theta|x) \propto L(\theta|x)p(\theta)\\
# log(p(\theta|x)) \propto log(L(\theta|x)p(\theta))\\
# log(p(\theta|x)) \propto log(L(\theta|x)+log(p(\theta))
# $$
# when an improper prior ($p(\theta$)) is used, the prior distribution does not integrates to 1 and the marginal likellihood can not converge to a finite value, and therefore it fails to act properly like a normalizing constant, which causes an improper posterior log posterior distribution.
